# %%
import pandas as pd

# %%
#FILTRANDO NOMES ATRAVÉS DE CARACATERES.

dados = {
    'Nome' : ['Mateus','Ana','Cristiano','André','Lucia'],
    'Curso' : ['Id.Média','Id.Média','Id.Média','Id.Média','Id.Média']
}

df= pd.DataFrame(dados)
filtro = df[df['Nome'].str.contains('^A')]
print ("Alunos que começa com a letra A:", filtro)
